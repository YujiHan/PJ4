# %%
import numpy as np
import global_feature
import local_feature

# %%
output_path_global = '/home/hanyuji/projects/PJ4/data/global_features/'
output_path_local = '/home/hanyuji/projects/PJ4/data/local_features/'
data_path = '/home/hanyuji/projects/PJ4/data/food_101/meta/'

# %% [markdown]
# # 1 读取全局特征

# %%
global_types = ['CLD', 'SCD', 'HIST']
local_types = ['sift', 'orb', 'surf']
dataset_types = ['train', 'test']

dataset_dic = {}

# %%
for global_type in global_types:
    for dataset_type in dataset_types:
        print(global_type)
        list_path = data_path + dataset_type+'.txt'
        data, labels =  loaddata_global.load_dataset(list_path, global_feature_type=global_type)
        np.save(f'{output_path_global}global_feature_{global_type}_{dataset_type}.npy',data)
        np.save(f'{output_path_global}global_label_{global_type}_{dataset_type}.npy',labels)
        
        dataset_dic[f'global_feature_{global_type}_{dataset_type}'] = data
        dataset_dic[f'global_label_{global_type}_{dataset_type}'] = labels
# Out:
# CLD
# load image: 0
# load image: 1
# load image: 2
# load image: 3
# load image: 4
# load image: 5
# load image: 6
# load image: 7
# load image: 8
# load image: 9
# load image: 10
# load image: 11
# load image: 12
# load image: 13
# load image: 14
# load image: 15
# load image: 16
# load image: 17
# load image: 18
# load image: 19
# load image: 20
# load image: 21
# load image: 22
# load image: 23
# load image: 24
# load image: 25
# load image: 26
# load image: 27
# load image: 28
# load image: 29
# load image: 30
# load image: 31
# load image: 32
# load image: 33
# load image: 34
# load image: 35
# load image: 36
# load image: 37
# load image: 38
# load image: 39
# load image: 40
# load image: 41
# load image: 42
# load image: 43
# load image: 44
# load image: 45
# load image: 46
# load image: 47
# load image: 48
# load image: 49
# load image: 50
# load image: 51
# load image: 52
# load image: 53
# load image: 54
# load image: 55
# load image: 56
# load image: 57
# load image: 58
# ...

# %%
for k in dataset_dic:
    print(k)
# Out:
# global_feature_CLD_train
# global_label_CLD_train
# global_feature_CLD_test
# global_label_CLD_test
# global_feature_SCD_train
# global_label_SCD_train
# global_feature_SCD_test
# global_label_SCD_test
# global_feature_HIST_train
# global_label_HIST_train
# global_feature_HIST_test
# global_label_HIST_test

# %%
np.array(dataset_dic['global_feature_CLD_train']).shape
# Out:
# (4500, 192)

# %%
np.array(dataset_dic['global_feature_HIST_train'])
# Out:
# array([[5.9512099e-03, 1.7214243e-04, 9.5907931e-04, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [8.4369205e-04, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.4040442e-02, 1.8985119e-01, 6.7493320e-02, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [0.0000000e+00, 3.1379441e-05, 8.7862433e-04, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [2.0849520e-02, 1.6835015e-03, 1.5993265e-02, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %% [markdown]
# # 2 局部特征

# %%
for local_type in local_types:
    for dataset_type in dataset_types:
        print(local_type)
        list_path = data_path + dataset_type+'.txt'
        data, labels =  loaddata_local.load_dataset(list_path, local_feature_type=local_type)
        np.save(f'{output_path_local}local_feature_{local_type}_{dataset_type}.npy',data)
        np.save(f'{output_path_local}local_label_{local_type}_{dataset_type}.npy',labels)
        
        dataset_dic[f'local_feature_{local_type}_{dataset_type}'] = data
        dataset_dic[f'local_label_{local_type}_{dataset_type}'] = labels
# Out:
# sift
# load image: 0
# load image: 1
# load image: 2
# load image: 3
# load image: 4
# load image: 5
# load image: 6
# load image: 7
# load image: 8
# load image: 9
# load image: 10
# load image: 11
# load image: 12
# load image: 13
# load image: 14
# load image: 15
# load image: 16
# load image: 17
# load image: 18
# load image: 19
# load image: 20
# load image: 21
# load image: 22
# load image: 23
# load image: 24
# load image: 25
# load image: 26
# load image: 27
# load image: 28
# load image: 29
# load image: 30
# load image: 31
# load image: 32
# load image: 33
# load image: 34
# load image: 35
# load image: 36
# load image: 37
# load image: 38
# load image: 39
# load image: 40
# load image: 41
# load image: 42
# load image: 43
# load image: 44
# load image: 45
# load image: 46
# load image: 47
# load image: 48
# load image: 49
# load image: 50
# load image: 51
# load image: 52
# load image: 53
# load image: 54
# load image: 55
# load image: 56
# load image: 57
# load image: 58
# ...

# %%
for local_type in local_types:
    for dataset_type in dataset_types:
        print(local_type)
        list_path = data_path + dataset_type + '.txt'
        data, labels = loaddata_local.load_dataset(
            list_path, local_feature_type=local_type
        )
        np.save(
            f'{output_path_local}local_feature_{local_type}_{dataset_type}.npy', data
        )
        np.save(
            f'{output_path_local}local_label_{local_type}_{dataset_type}.npy', labels
        )

        dataset_dic[f'local_feature_{local_type}_{dataset_type}'] = data
        dataset_dic[f'local_label_{local_type}_{dataset_type}'] = labels
